# %% [markdown]
# # Загрузка файлов

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\zPad\OneDrive\Documents\Study\MIPT\Study\Project_2024_12\test-3\review_flamp_yandex_v6.csv",
    sep=",",
)
display(df.head(2))
dff = pd.read_csv(
    r"C:\Users\zPad\OneDrive\Documents\Study\MIPT\Study\Project_2024_12\feature_extraction\features.csv",
    sep=",",
)
display(dff.head(2))
# Out:
#            place_id    name_primary         name_extension    city  \
# 0  4504127908348140             495  пивоваренный ресторан  Москва
# 1  4504127908348160  Bora bora cafe               ресторан  Москва
#
#                       address        lat        lon  rating_decimal  \
# 0  Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1      Ореховый бульвар, 14к3  55.609493  37.719954             4.0
#
#    reviews_count  business_lunch  avg_price  \
# 0              1             0.0     1500.0
# 1              3             1.0     1500.0
#
#                                               review  rating source
# 0  в принципе, нормальный ресторанчик при отеле. ...     5.0  flamp
# 1  есть такой ресторан на юге москвы, по названию...     5.0  flamp
#            place_id                                            reviews  \
# 0  4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1  4504127908348160  есть такой ресторан на юге москвы, по названию...
#
#                                             features    name_primary  \
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...             495
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...  Bora bora cafe
#
#           name_extension    city                     address        lat  \
# 0  пивоваренный ресторан  Москва  Олимпийский проспект, 18/1  55.785009
# 1               ресторан  Москва      Ореховый бульвар, 14к3  55.609493
#
#          lon  rating_decimal  reviews_count  business_lunch  avg_price  \
# 0  37.624123             5.0              1             0.0     1500.0
# 1  37.719954             4.0              3             1.0     1500.0
#
#    rating source
# 0     5.0  flamp
# 1     5.0  flamp

# %%
df["review"] = df["review"].fillna("", inplace=False)
dff["reviews"] = dff["reviews"].fillna("", inplace=False)
dff["features"] = dff["features"].fillna("", inplace=False)

# %% [markdown]
# # Обработка

# %%
# функция обработки необходимых колонок
def process_column(input_df, input_dff, func):
    df = input_df.copy()
    dff = input_dff.copy()

    df["review_clean"] = df["review_clean"].apply(func)
    dff["reviews_clean"] = dff["reviews_clean"].apply(func)
    dff["features_clean"] = dff["features_clean"].apply(func)
    display(df.head(2))
    display(dff.head(2))

    return df, dff

# %%
initial_df = df.copy()
initial_dff = dff.copy()

df = initial_df.copy()
dff = initial_dff.copy()

df["review_clean"] = df["review"]
dff["reviews_clean"] = dff["reviews"]
dff["features_clean"] = dff["features"]

# %% [markdown]
# ## 1. Приведение к нижнему регистру

# %%
# Приведение к нижнему регистру
def to_lower(text):
    return text.lower()


df_1, dff_1 = process_column(df, dff, to_lower)
# Out:
#            place_id    name_primary         name_extension    city  \
# 0  4504127908348140             495  пивоваренный ресторан  Москва
# 1  4504127908348160  Bora bora cafe               ресторан  Москва
#
#                       address        lat        lon  rating_decimal  \
# 0  Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1      Ореховый бульвар, 14к3  55.609493  37.719954             4.0
#
#    reviews_count  business_lunch  avg_price  \
# 0              1             0.0     1500.0
# 1              3             1.0     1500.0
#
#                                               review  rating source  \
# 0  в принципе, нормальный ресторанчик при отеле. ...     5.0  flamp
# 1  есть такой ресторан на юге москвы, по названию...     5.0  flamp
#
#                                         review_clean
# 0  в принципе, нормальный ресторанчик при отеле. ...
# 1  есть такой ресторан на юге москвы, по названию...
#            place_id                                            reviews  \
# 0  4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1  4504127908348160  есть такой ресторан на юге москвы, по названию...
#
#                                             features    name_primary  \
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...             495
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...  Bora bora cafe
#
#           name_extension    city                     address        lat  \
# 0  пивоваренный ресторан  Москва  Олимпийский проспект, 18/1  55.785009
# 1               ресторан  Москва      Ореховый бульвар, 14к3  55.609493
#
#          lon  rating_decimal  reviews_count  business_lunch  avg_price  \
# 0  37.624123             5.0              1             0.0     1500.0
# 1  37.719954             4.0              3             1.0     1500.0
#
#    rating source                                      reviews_clean  \
# 0     5.0  flamp  в принципе, нормальный ресторанчик при отеле. ...
# 1     5.0  flamp  есть такой ресторан на юге москвы, по названию...
#
#                                       features_clean
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...

# %% [markdown]
# ## 2. удаление лишних символов

# %%
# удаление лишних символов
import re


def clean_text(text):
    return re.sub(r"[^\w\s\n]", " ", text)


df_2, dff_2 = process_column(df_1, dff_1, clean_text)
# Out:
#            place_id    name_primary         name_extension    city  \
# 0  4504127908348140             495  пивоваренный ресторан  Москва
# 1  4504127908348160  Bora bora cafe               ресторан  Москва
#
#                       address        lat        lon  rating_decimal  \
# 0  Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1      Ореховый бульвар, 14к3  55.609493  37.719954             4.0
#
#    reviews_count  business_lunch  avg_price  \
# 0              1             0.0     1500.0
# 1              3             1.0     1500.0
#
#                                               review  rating source  \
# 0  в принципе, нормальный ресторанчик при отеле. ...     5.0  flamp
# 1  есть такой ресторан на юге москвы, по названию...     5.0  flamp
#
#                                         review_clean
# 0  в принципе нормальный ресторанчик при отеле по...
# 1  есть такой ресторан на юге москвы по названию ...
#            place_id                                            reviews  \
# 0  4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1  4504127908348160  есть такой ресторан на юге москвы, по названию...
#
#                                             features    name_primary  \
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...             495
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...  Bora bora cafe
#
#           name_extension    city                     address        lat  \
# 0  пивоваренный ресторан  Москва  Олимпийский проспект, 18/1  55.785009
# 1               ресторан  Москва      Ореховый бульвар, 14к3  55.609493
#
#          lon  rating_decimal  reviews_count  business_lunch  avg_price  \
# 0  37.624123             5.0              1             0.0     1500.0
# 1  37.719954             4.0              3             1.0     1500.0
#
#    rating source                                      reviews_clean  \
# 0     5.0  flamp  в принципе нормальный ресторанчик при отеле по...
# 1     5.0  flamp  есть такой ресторан на юге москвы по названию ...
#
#                                       features_clean
# 0  бизнесланч биточки вкусная еда гречотто кофе л...
# 1  бизнесланчи вкусная еда вкусный стейк деловой ...

# %% [markdown]
# ## 3. удаление пунктуации

# %%
# удаление пунктуации
import string


def remove_punctuation(text):
    # Удаляем знаки пунктуации
    translator = str.maketrans(string.punctuation, " " * len(string.punctuation))
    return text.translate(translator).strip()


df_3, dff_3 = process_column(df_2, dff_2, remove_punctuation)
# Out:
#            place_id    name_primary         name_extension    city  \
# 0  4504127908348140             495  пивоваренный ресторан  Москва
# 1  4504127908348160  Bora bora cafe               ресторан  Москва
#
#                       address        lat        lon  rating_decimal  \
# 0  Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1      Ореховый бульвар, 14к3  55.609493  37.719954             4.0
#
#    reviews_count  business_lunch  avg_price  \
# 0              1             0.0     1500.0
# 1              3             1.0     1500.0
#
#                                               review  rating source  \
# 0  в принципе, нормальный ресторанчик при отеле. ...     5.0  flamp
# 1  есть такой ресторан на юге москвы, по названию...     5.0  flamp
#
#                                         review_clean
# 0  в принципе нормальный ресторанчик при отеле по...
# 1  есть такой ресторан на юге москвы по названию ...
#            place_id                                            reviews  \
# 0  4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1  4504127908348160  есть такой ресторан на юге москвы, по названию...
#
#                                             features    name_primary  \
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...             495
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...  Bora bora cafe
#
#           name_extension    city                     address        lat  \
# 0  пивоваренный ресторан  Москва  Олимпийский проспект, 18/1  55.785009
# 1               ресторан  Москва      Ореховый бульвар, 14к3  55.609493
#
#          lon  rating_decimal  reviews_count  business_lunch  avg_price  \
# 0  37.624123             5.0              1             0.0     1500.0
# 1  37.719954             4.0              3             1.0     1500.0
#
#    rating source                                      reviews_clean  \
# 0     5.0  flamp  в принципе нормальный ресторанчик при отеле по...
# 1     5.0  flamp  есть такой ресторан на юге москвы по названию ...
#
#                                       features_clean
# 0  бизнесланч биточки вкусная еда гречотто кофе л...
# 1  бизнесланчи вкусная еда вкусный стейк деловой ...

# %% [markdown]
# ## 4. лемматизация

# %%
import spacy

# Загружаем модель для русского языка
nlp = spacy.load("ru_core_news_sm")

# Пример текста
text = "в принципе нормальный ресторанчик при отеле "

# Применение лемматизации к одному тексту
doc = nlp(text)
lemmas = [token.lemma_ for token in doc]
lemmatized_text = " ".join(lemmas)

# Вывод результата
print(lemmatized_text)
# Out:
# в принцип нормальный ресторанчик при отель

# %%
# Лемматизация
import spacy

# Загружаем модель для русского языка
nlp = spacy.load("ru_core_news_sm")


def lemmatize(text):
    doc = nlp(text)
    lemmas = [token.lemma_ for token in doc]
    return " ".join(lemmas)


df_4, dff_4 = process_column(df_3, dff_3, lemmatize)
# Out:
#            place_id    name_primary         name_extension    city  \
# 0  4504127908348140             495  пивоваренный ресторан  Москва
# 1  4504127908348160  Bora bora cafe               ресторан  Москва
#
#                       address        lat        lon  rating_decimal  \
# 0  Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1      Ореховый бульвар, 14к3  55.609493  37.719954             4.0
#
#    reviews_count  business_lunch  avg_price  \
# 0              1             0.0     1500.0
# 1              3             1.0     1500.0
#
#                                               review  rating source  \
# 0  в принципе, нормальный ресторанчик при отеле. ...     5.0  flamp
# 1  есть такой ресторан на юге москвы, по названию...     5.0  flamp
#
#                                         review_clean
# 0  в принцип нормальный ресторанчик при отель пос...
# 1  быть такой ресторан на юг москва по название в...
#            place_id                                            reviews  \
# 0  4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1  4504127908348160  есть такой ресторан на юге москвы, по названию...
#
#                                             features    name_primary  \
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...             495
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...  Bora bora cafe
#
#           name_extension    city                     address        lat  \
# 0  пивоваренный ресторан  Москва  Олимпийский проспект, 18/1  55.785009
# 1               ресторан  Москва      Ореховый бульвар, 14к3  55.609493
#
#          lon  rating_decimal  reviews_count  business_lunch  avg_price  \
# 0  37.624123             5.0              1             0.0     1500.0
# 1  37.719954             4.0              3             1.0     1500.0
#
#    rating source                                      reviews_clean  \
# 0     5.0  flamp  в принцип нормальный ресторанчик при отель пос...
# 1     5.0  flamp  быть такой ресторан на юг москва по название в...
#
#                                       features_clean
# 0  бизнесланч биточки вкусный еда гречотто кофе л...
# 1  бизнесланчи вкусный еда вкусный стейк деловой ...

# %% [markdown]
# ## 5. удаление стоп-слов

# %%
# Удаляем стоп-слова
no_stopwords_reviews = []


def remove_stopwords(text):
    if pd.isna(text):
        return ""
    doc = nlp(text)
    # Удаляем только те токены, которые не являются стоп-словами
    filtered_tokens = [token.text for token in doc if not token.is_stop]
    return " ".join(filtered_tokens)


df_5, dff_5 = process_column(df_4, dff_4, remove_stopwords)
# Out:
#            place_id    name_primary         name_extension    city  \
# 0  4504127908348140             495  пивоваренный ресторан  Москва
# 1  4504127908348160  Bora bora cafe               ресторан  Москва
#
#                       address        lat        lon  rating_decimal  \
# 0  Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1      Ореховый бульвар, 14к3  55.609493  37.719954             4.0
#
#    reviews_count  business_lunch  avg_price  \
# 0              1             0.0     1500.0
# 1              3             1.0     1500.0
#
#                                               review  rating source  \
# 0  в принципе, нормальный ресторанчик при отеле. ...     5.0  flamp
# 1  есть такой ресторан на юге москвы, по названию...     5.0  flamp
#
#                                         review_clean
# 0  принцип нормальный ресторанчик отель выезд ход...
# 1  ресторан юг москва название    окунуться франц...
#            place_id                                            reviews  \
# 0  4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1  4504127908348160  есть такой ресторан на юге москвы, по названию...
#
#                                             features    name_primary  \
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...             495
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...  Bora bora cafe
#
#           name_extension    city                     address        lat  \
# 0  пивоваренный ресторан  Москва  Олимпийский проспект, 18/1  55.785009
# 1               ресторан  Москва      Ореховый бульвар, 14к3  55.609493
#
#          lon  rating_decimal  reviews_count  business_lunch  avg_price  \
# 0  37.624123             5.0              1             0.0     1500.0
# 1  37.719954             4.0              3             1.0     1500.0
#
#    rating source                                      reviews_clean  \
# 0     5.0  flamp  принцип нормальный ресторанчик отель выезд ход...
# 1     5.0  flamp  ресторан юг москва название    окунуться франц...
#
#                                       features_clean
# 0  бизнесланч биточки вкусный еда гречотто кофе л...
# 1  бизнесланчи вкусный еда вкусный стейк деловой ...

# %% [markdown]
# ## 6. удаление общих слов

# %% [markdown]
# .# удаление общих слов
# unwanted_words = [
#     "съедобный",
#     "простой",
#     "нейтральный",
#     "обычный",
#     "комфортный",
#     "привычный",
#     "тёплый",
#     "спокойный",
#     "понятный",
#     "общий",
#     "быть",
#     "такой",
#     "какой",
#     "еда",
#     "вкусный",
#     "нормальный",
# ]
# unwanted_words = set(unwanted_words)
#
#
# def remove_unwanted_words(text):
#     if pd.isna(text):
#         return ""
#     doc = nlp(text)
#     # Удаляем только те токены, леммы которых присутствуют в unwanted_adjectives
#     filtered_tokens = [
#         token.text for token in doc if token.lemma_ not in unwanted_words
#     ]
#     return " ".join(filtered_tokens)
#
#
# df_6, dff_6 = process_column(df_5, dff_5, remove_unwanted_words)

# %% [markdown]
# ## 7. удаление глаголов

# %%
def remove_verbs(text):
    if pd.isna(text):
        return ""
    doc = nlp(text)
    # Удаляем все токены, у которых POS-тег VERB
    filtered_tokens = [token.text for token in doc if token.pos_ != "VERB"]
    filtered_text = " ".join(filtered_tokens)
    # Очистка лишних пробелов и знаков препинания
    filtered_text = re.sub(r"\s+,", ",", filtered_text)
    filtered_text = re.sub(r",\s+", ", ", filtered_text)
    filtered_text = re.sub(r"\s+\.", ".", filtered_text)
    return filtered_text

# %%
df_5["review_clean_no_verbs"] = df_5["review_clean"].apply(remove_verbs)
dff_5["reviews_clean_no_verbs"] = dff_5["reviews_clean"].apply(remove_verbs)
dff_5["features_clean_no_verbs"] = dff_5["features_clean"].apply(remove_verbs)

# %% [markdown]
# ## 8. удаление всех прилагательных - только для features

# %%
def remove_adjectives(text):
    if pd.isna(text):
        return ""
    doc = nlp(text)
    # Удаляем все токены, у которых POS-тег ADJ
    filtered_tokens = [token.text for token in doc if token.pos_ != "ADJ"]
    filtered_text = " ".join(filtered_tokens)
    # Очистка лишних пробелов и знаков препинания
    filtered_text = re.sub(r"\s+,", ",", filtered_text)
    filtered_text = re.sub(r",\s+", ", ", filtered_text)
    filtered_text = re.sub(r"\s+\.", ".", filtered_text)
    return filtered_text

# %%
text = "бизнес - ланчи , вкусный еда , вкусный стейк отличное обслуживание и вкусные блюда, приятная атмосфера и вкусная еда,быстрое обслуживание но среднее качество еды, вкусный кофе и хороший сервис"
remove_adjectives(text)
# Out:
# 'бизнес - ланчи, еда, стейк обслуживание и блюда, атмосфера и еда, обслуживание но качество еды, кофе и сервис'

# %%
df_5["review_clean_no_adj"] = df_5["review_clean"].apply(remove_adjectives)
dff_5["reviews_clean_no_adj"] = dff_5["reviews_clean"].apply(remove_adjectives)
dff_5["features_clean_no_adj"] = dff_5["features_clean"].apply(remove_adjectives)

# %% [markdown]
# ## ultimate removal

# %%
df_5["review_clean_no_verbs_no_adj"] = df_5["review_clean_no_verbs"].apply(
    remove_adjectives
)
dff_5["reviews_clean_no_verbs_no_adj"] = dff_5["reviews_clean_no_verbs"].apply(
    remove_adjectives
)
dff_5["features_clean_no_verbs_no_adj"] = dff_5["features_clean_no_verbs"].apply(
    remove_adjectives
)

# %%
df_5.to_csv("review_flamp_yandex_v7.csv", index=False)
dff_5.to_csv("review_flamp_yandex_v7_keywords.csv", index=False)

# %%
display(df_5.head(2))
display(dff_5.head(2))
# Out:
#            place_id    name_primary         name_extension    city  \
# 0  4504127908348140             495  пивоваренный ресторан  Москва
# 1  4504127908348160  Bora bora cafe               ресторан  Москва
#
#                       address        lat        lon  rating_decimal  \
# 0  Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1      Ореховый бульвар, 14к3  55.609493  37.719954             4.0
#
#    reviews_count  business_lunch  avg_price  \
# 0              1             0.0     1500.0
# 1              3             1.0     1500.0
#
#                                               review  rating source  \
# 0  в принципе, нормальный ресторанчик при отеле. ...     5.0  flamp
# 1  есть такой ресторан на юге москвы, по названию...     5.0  flamp
#
#                                         review_clean  \
# 0  принцип нормальный ресторанчик отель выезд ход...
# 1  ресторан юг москва название    окунуться франц...
#
#                                review_clean_no_verbs  \
# 0  принцип нормальный ресторанчик отель выезд сюд...
# 1  ресторан юг москва название     французский по...
#
#                                  review_clean_no_adj  \
# 0  принцип ресторанчик отель выезд ходить сюда би...
# 1  ресторан юг москва название     окунуться поли...
#
#                         review_clean_no_verbs_no_adj
# 0  принцип ресторанчик отель выезд сюда бизнеслан...
# 1  ресторан юг москва название      полинезия бер...
#            place_id                                            reviews  \
# 0  4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1  4504127908348160  есть такой ресторан на юге москвы, по названию...
#
#                                             features    name_primary  \
# 0  бизнес-ланч, биточки, вкусная еда, гречотто, к...             495
# 1  бизнес-ланчи, вкусная еда, вкусный стейк, дело...  Bora bora cafe
#
#           name_extension    city                     address        lat  \
# 0  пивоваренный ресторан  Москва  Олимпийский проспект, 18/1  55.785009
# 1               ресторан  Москва      Ореховый бульвар, 14к3  55.609493
#
#          lon  rating_decimal  ...  rating  source  \
# 0  37.624123             5.0  ...     5.0   flamp
# 1  37.719954             4.0  ...     5.0   flamp
#
#                                        reviews_clean  \
# 0  принцип нормальный ресторанчик отель выезд ход...
# 1  ресторан юг москва название    окунуться франц...
#
#                                       features_clean  \
# 0  бизнесланч биточки вкусный еда гречотто кофе л...
# 1  бизнесланчи вкусный еда вкусный стейк деловой ...
#
#                               reviews_clean_no_verbs  \
# 0  принцип нормальный ресторанчик отель выезд сюд...
# 1  ресторан юг москва название     французский по...
#
#                              features_clean_no_verbs  \
# 0  бизнесланч биточки вкусный еда гречотто кофе л...
# 1  бизнесланчи вкусный еда вкусный стейк деловой ...
#
#                                 reviews_clean_no_adj  \
# 0  принцип ресторанчик отель выезд ходить сюда би...
# 1  ресторан юг москва название     окунуться поли...
#
#                                features_clean_no_adj  \
# 0  бизнесланч биточки еда гречотто кофе латте цен...
# 1  еда стейк обед стиль мастерклассы доверие кухн...
#
#                        reviews_clean_no_verbs_no_adj  \
# 0  принцип ресторанчик отель выезд сюда бизнеслан...
# 1  ресторан юг москва название      полинезия бер...
#
#                       features_clean_no_verbs_no_adj
# 0  бизнесланч биточки еда гречотто кофе латте цен...
# 1  еда стейк обед стиль мастерклассы доверие кухн...
#
# [2 rows x 23 columns]

# %%
df_5["len"] = df_5["review"].apply(len)
dff_5["len"] = dff_5["features_clean_no_verbs_no_adj"].apply(len)

grouped_stats = df_5.groupby("source")["len"].describe()
display(grouped_stats)
grouped_stats = dff_5.groupby("source")["len"].describe()
display(grouped_stats)
# Out:
#           count        mean         std   min    25%    50%    75%     max
# source
# flamp   23127.0  421.914688  452.478034  82.0  175.0  269.0  484.0  7997.0
# yandex  24707.0  294.361112  270.476964   6.0  142.0  211.0  354.0  4793.0
#          count        mean         std  min   25%   50%    75%     max
# source
# flamp   2550.0  130.760000  134.525377  0.0  50.0  97.0  174.0  1575.0
# yandex  7211.0   84.261406   64.774430  0.0  39.0  65.0  113.0  1028.0

# %% [markdown]
# # оценка

# %%
df_6 = df_5.copy()
dff_6 = dff_5.copy()

df_6 = df_6[(df_6["len"] > 7)]
df_6.dropna(subset=["review_clean_no_verbs_no_adj"], inplace=True)
dff_6 = dff_6[(dff_6["len"] > 7)]
dff_6.dropna(subset=["reviews_clean_no_verbs_no_adj"], inplace=True)
dff_6.dropna(subset=["features_clean_no_verbs_no_adj"], inplace=True)

# %%
grouped_stats = df_6.groupby("source")["len"].describe()
display(grouped_stats)
grouped_stats = dff_6.groupby("source")["len"].describe()
display(grouped_stats)
# Out:
#           count        mean         std  min   25%    50%    75%     max
# source
# flamp   23123.0  155.723392  173.191126  8.0  63.0  101.0  180.0  4721.0
# yandex  24565.0  114.388683  103.953868  8.0  54.0   84.0  139.0  2183.0
#          count        mean         std  min   25%   50%    75%     max
# source
# flamp   2540.0  131.261024  134.552189  8.0  50.0  98.0  174.0  1575.0
# yandex  7105.0   85.464180   64.496501  8.0  39.0  66.0  114.0  1028.0

# %%
df_6.to_csv("review_flamp_yandex_v7.csv", index=False)
dff_6.to_csv("review_flamp_yandex_v7_keywords.csv", index=False)

# %% [markdown]
# # split

# %%
def split_review(review: str, min_len=100, max_len=500):
    # Удаляем строки короче 100 символов
    if len(review) < min_len:
        return []

    # Если длина уже в пределах [100;500], просто возвращаем в списке
    if len(review) <= max_len:
        return [review]

    # Иначе разбиваем на части
    parts = []
    start = 0
    n = len(review)

    while start < n:
        # Определяем максимально допустимый конец текущего куска
        end = min(start + max_len, n)

        # Если мы уже близко к концу, и оставшийся текст короче 100 символов, то проверяем,
        # стоит ли вообще добавлять этот кусок
        if n - start < min_len:
            # Оставшийся текст слишком короткий, пропускаем
            break

        # Если текущий блок итак удовлетворяет условию [100;500], проверим, не надо ли его корректировать по пробелу
        # Попытаемся найти пробел, чтобы не обрывать слово
        # Если end == n (конец строки), то ничего искать не нужно
        if end < n:
            # Найдем ближайший пробел с конца до текущей максимальной границы
            space_pos = review.rfind(" ", start, end)
            if space_pos == -1:
                # Не нашли пробел, придётся отрезать на max_len символах.
                # Но если кусок меньше 100 символов, это плохо, тогда придётся сдвигать границу вперёд пока не найдём пробел или
                # достичь min_len.
                # Однако если нет пробела до max_len, просто разрежем по max_len (не очень красиво, но выбора нет)
                space_pos = end
            else:
                # Проверим длину найденного куска
                if space_pos - start < min_len:
                    # Если слишком коротко, попробуем найти пробел после space_pos, двигаясь вперёд
                    # чтобы был кусок не менее min_len.
                    forward_space = review.find(" ", space_pos + 1, end)
                    if forward_space == -1:
                        # Нет подходящего пробела дальше - придется взять max_len символов
                        space_pos = end
                    else:
                        # Если forward_space всё еще не дотягивает до min_len, будем искать дальше
                        # Но чтобы упростить, можно просто взять end, если не получается
                        # Это сложная логика, можно упростить, но для наглядности пусть так
                        if forward_space - start < min_len:
                            space_pos = end
                        else:
                            space_pos = forward_space
        else:
            # Здесь end == n, то есть мы на последнем куске
            space_pos = end

        current_part = review[start:space_pos].strip()

        # Если текущий кусок всё-таки меньше 100, то нужно либо расширить его, либо отказаться
        if len(current_part) < min_len:
            # Попытка расширить:
            # Если пространство для расширения есть (end < n), расширим до max_len или конца строки
            # Но мы уже пытались. В случае если расширить нельзя - пропускаем остаток.
            # Здесь для упрощения просто выйдем из цикла.
            break

        parts.append(current_part)
        start = space_pos
        # Пропускаем возможные лишние пробелы
        while start < n and review[start] == " ":
            start += 1

    return parts

# %%
df_7 = df_6.copy()
df_7["split_reviews"] = df_7["review"].apply(split_review)

# %%
df_7 = df_7[df_7["split_reviews"].apply(lambda x: len(x) > 0)]
df_7 = df_7.explode("split_reviews").reset_index(drop=True)
df_7
# Out:
#                 place_id            name_primary         name_extension  \
# 0       4504127908348140                     495  пивоваренный ресторан
# 1       4504127908348160          Bora bora cafe               ресторан
# 2       4504127908348160          Bora bora cafe               ресторан
# 3       4504127908348160          Bora bora cafe               ресторан
# 4       4504127908348160          Bora bora cafe               ресторан
# ...                  ...                     ...                    ...
# 55171  70000001091778281      караоке-клуб маска               ресторан
# 55172  70000001091778282             шаурма 1001               ресторан
# 55173  70000001091778283  petruccio. pizza&pasta               ресторан
# 55174  70000001091778283  petruccio. pizza&pasta               ресторан
# 55175  70000001091778283  petruccio. pizza&pasta               ресторан
#
#          city                     address        lat        lon  \
# 0      Москва  Олимпийский проспект, 18/1  55.785009  37.624123
# 1      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# 2      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# 3      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# 4      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# ...       ...                         ...        ...        ...
# 55171  Москва        улица Маросейка, 7/8  55.757592  37.632880
# 55172  Москва   Братиславская улица, 31к1  55.652684  37.767690
# 55173  Москва     улица Юных Ленинцев, 52  55.699796  37.765354
# 55174  Москва     улица Юных Ленинцев, 52  55.699796  37.765354
# 55175  Москва     улица Юных Ленинцев, 52  55.699796  37.765354
#
#        rating_decimal  reviews_count  business_lunch  avg_price  \
# 0                 5.0              1             0.0     1500.0
# 1                 4.0              3             1.0     1500.0
# 2                 4.0              3             1.0     1500.0
# 3                 4.0              3             1.0     1500.0
# 4                 4.0              3             1.0     1500.0
# ...               ...            ...             ...        ...
# 55171             5.0              5             0.0        NaN
# 55172             1.0              1             0.0        NaN
# 55173             5.0              3             0.0        NaN
# 55174             5.0              3             0.0        NaN
# 55175             1.0              3             0.0        NaN
#
#                                                   review  rating  source  \
# 0      в принципе, нормальный ресторанчик при отеле. ...     5.0   flamp
# 1      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# 2      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# 3      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# 4      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# ...                                                  ...     ...     ...
# 55171  хороший караоке клуб! бронировали vip. все отл...     5.0  yandex
# 55172  залетели ночью с друзьями, разбудили работника...     1.0  yandex
# 55173  очень вкусная пицца. нравится их система лояль...     5.0  yandex
# 55174  пицца детям понравилась, интерьер очень интере...     5.0  yandex
# 55175  сегодня заказали у вас доставку. перепутали на...     1.0  yandex
#
#                                             review_clean  \
# 0      принцип нормальный ресторанчик отель выезд ход...
# 1      ресторан юг москва название    окунуться франц...
# 2      ресторан юг москва название    окунуться франц...
# 3      ресторан юг москва название    окунуться франц...
# 4      ресторан юг москва название    окунуться франц...
# ...                                                  ...
# 55171  хороший караоке клуб бронировать vip отлично н...
# 55172  залететь ночь друг разбудить работник сделать ...
# 55173  вкусный пицца нравиться система лояльность раз...
# 55174  пицца ребёнок понравиться интерьер интересный ...
# 55175  сегодня заказать доставка перепутать пасты доб...
#
#                                    review_clean_no_verbs  \
# 0      принцип нормальный ресторанчик отель выезд сюд...
# 1      ресторан юг москва название     французский по...
# 2      ресторан юг москва название     французский по...
# 3      ресторан юг москва название     французский по...
# 4      ресторан юг москва название     французский по...
# ...                                                  ...
# 55171  хороший караоке клуб vip отлично музыка 2 час ...
# 55172  ночь друг работник шаурму штука самсы говядина...
# 55173  вкусный пицца система лояльность раз приятно ц...
# 55174  пицца ребёнок интерьер интересный кактейли вку...
# 55175  сегодня доставка пасты сырой креветка безвкусн...
#
#                                      review_clean_no_adj  \
# 0      принцип ресторанчик отель выезд ходить сюда би...
# 1      ресторан юг москва название     окунуться поли...
# 2      ресторан юг москва название     окунуться поли...
# 3      ресторан юг москва название     окунуться поли...
# 4      ресторан юг москва название     окунуться поли...
# ...                                                  ...
# 55171  караоке клуб бронировать vip отлично насладить...
# 55172  залететь ночь друг разбудить работник сделать ...
# 55173  пицца нравиться система лояльность раз сбивать...
# 55174  пицца ребёнок понравиться интерьер заказать ка...
# 55175  сегодня заказать доставка перепутать пасты доб...
#
#                             review_clean_no_verbs_no_adj   len  \
# 0      принцип ресторанчик отель выезд сюда бизнеслан...   212
# 1      ресторан юг москва название      полинезия бер...  1156
# 2      ресторан юг москва название      полинезия бер...  1156
# 3      ресторан юг москва название      полинезия бер...  1156
# 4      ресторан юг москва название      полинезия бер...  1156
# ...                                                  ...   ...
# 55171  караоке клуб vip отлично музыка 2 час 2000 руб...    83
# 55172  ночь друг работник шаурму штука самсы говядина...    79
# 55173  пицца система лояльность раз цена обслуживание...    68
# 55174  пицца ребёнок интерьер интересный кактейли под...    63
# 55175  сегодня доставка пасты креветка трубка берёте ...    91
#
#                                            split_reviews
# 0      в принципе, нормальный ресторанчик при отеле. ...
# 1      есть такой ресторан на юге москвы, по названию...
# 2      протяжении четырех часов!,с 1400 до 1800. цены...
# 3      вид из окна ночью на каширское шоссе и такое б...
# 4      брали салат из весеннего меню от шефповара рес...
# ...                                                  ...
# 55171  хороший караоке клуб! бронировали vip. все отл...
# 55172  залетели ночью с друзьями, разбудили работника...
# 55173  очень вкусная пицца. нравится их система лояль...
# 55174  пицца детям понравилась, интерьер очень интере...
# 55175  сегодня заказали у вас доставку. перепутали на...
#
# [55176 rows x 20 columns]

# %%
df_7["len"] = df_7["split_reviews"].apply(len)

grouped_stats = df_7.groupby("source")["len"].describe()
display(grouped_stats)
# Out:
#           count        mean         std    min    25%    50%    75%    max
# source
# flamp   30302.0  318.828559  144.716089  100.0  184.0  300.0  493.0  500.0
# yandex  24874.0  281.680912  134.111341  100.0  166.0  242.0  400.0  500.0

# %%
df_7.to_csv("review_flamp_yandex_v7_exploaded.csv", index=False)

# %%
df_7 = df_7[(df_7["rating"] > 3) & (df_7["rating_decimal"] > 3)]
df_7
# Out:
#                 place_id            name_primary         name_extension  \
# 0       4504127908348140                     495  пивоваренный ресторан
# 1       4504127908348160          Bora bora cafe               ресторан
# 2       4504127908348160          Bora bora cafe               ресторан
# 3       4504127908348160          Bora bora cafe               ресторан
# 4       4504127908348160          Bora bora cafe               ресторан
# ...                  ...                     ...                    ...
# 55169  70000001091778281      караоке-клуб маска               ресторан
# 55170  70000001091778281      караоке-клуб маска               ресторан
# 55171  70000001091778281      караоке-клуб маска               ресторан
# 55173  70000001091778283  petruccio. pizza&pasta               ресторан
# 55174  70000001091778283  petruccio. pizza&pasta               ресторан
#
#          city                     address        lat        lon  \
# 0      Москва  Олимпийский проспект, 18/1  55.785009  37.624123
# 1      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# 2      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# 3      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# 4      Москва      Ореховый бульвар, 14к3  55.609493  37.719954
# ...       ...                         ...        ...        ...
# 55169  Москва        улица Маросейка, 7/8  55.757592  37.632880
# 55170  Москва        улица Маросейка, 7/8  55.757592  37.632880
# 55171  Москва        улица Маросейка, 7/8  55.757592  37.632880
# 55173  Москва     улица Юных Ленинцев, 52  55.699796  37.765354
# 55174  Москва     улица Юных Ленинцев, 52  55.699796  37.765354
#
#        rating_decimal  reviews_count  business_lunch  avg_price  \
# 0                 5.0              1             0.0     1500.0
# 1                 4.0              3             1.0     1500.0
# 2                 4.0              3             1.0     1500.0
# 3                 4.0              3             1.0     1500.0
# 4                 4.0              3             1.0     1500.0
# ...               ...            ...             ...        ...
# 55169             5.0              5             0.0        NaN
# 55170             5.0              5             0.0        NaN
# 55171             5.0              5             0.0        NaN
# 55173             5.0              3             0.0        NaN
# 55174             5.0              3             0.0        NaN
#
#                                                   review  rating  source  \
# 0      в принципе, нормальный ресторанчик при отеле. ...     5.0   flamp
# 1      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# 2      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# 3      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# 4      есть такой ресторан на юге москвы, по названию...     5.0   flamp
# ...                                                  ...     ...     ...
# 55169  посещали данное караоке 17.06.23 , остались до...     5.0  yandex
# 55170  ходили с друзьями в клуб праздновать мое день ...     5.0  yandex
# 55171  хороший караоке клуб! бронировали vip. все отл...     5.0  yandex
# 55173  очень вкусная пицца. нравится их система лояль...     5.0  yandex
# 55174  пицца детям понравилась, интерьер очень интере...     5.0  yandex
#
#                                             review_clean  \
# 0      принцип нормальный ресторанчик отель выезд ход...
# 1      ресторан юг москва название    окунуться франц...
# 2      ресторан юг москва название    окунуться франц...
# 3      ресторан юг москва название    окунуться франц...
# 4      ресторан юг москва название    окунуться франц...
# ...                                                  ...
# 55169  посещать караоке 170623    остаться довольный ...
# 55170  ходить друг клуб праздновать день рождение бро...
# 55171  хороший караоке клуб бронировать vip отлично н...
# 55173  вкусный пицца нравиться система лояльность раз...
# 55174  пицца ребёнок понравиться интерьер интересный ...
#
#                                    review_clean_no_verbs  \
# 0      принцип нормальный ресторанчик отель выезд сюд...
# 1      ресторан юг москва название     французский по...
# 2      ресторан юг москва название     французский по...
# 3      ресторан юг москва название     французский по...
# 4      ресторан юг москва название     французский по...
# ...                                                  ...
# 55169  караоке 170623     довольный звук хороший кухн...
# 55170  друг клуб день рождение vipкомнату отлично кар...
# 55171  хороший караоке клуб vip отлично музыка 2 час ...
# 55173  вкусный пицца система лояльность раз приятно ц...
# 55174  пицца ребёнок интерьер интересный кактейли вку...
#
#                                      review_clean_no_adj  \
# 0      принцип ресторанчик отель выезд ходить сюда би...
# 1      ресторан юг москва название     окунуться поли...
# 2      ресторан юг москва название     окунуться поли...
# 3      ресторан юг москва название     окунуться поли...
# 4      ресторан юг москва название     окунуться поли...
# ...                                                  ...
# 55169  посещать караоке 170623     остаться звук кухн...
# 55170  ходить друг клуб праздновать день рождение бро...
# 55171  караоке клуб бронировать vip отлично насладить...
# 55173  пицца нравиться система лояльность раз сбивать...
# 55174  пицца ребёнок понравиться интерьер заказать ка...
#
#                             review_clean_no_verbs_no_adj  len  \
# 0      принцип ресторанчик отель выезд сюда бизнеслан...  492
# 1      ресторан юг москва название      полинезия бер...  493
# 2      ресторан юг москва название      полинезия бер...  499
# 3      ресторан юг москва название      полинезия бер...  495
# 4      ресторан юг москва название      полинезия бер...  492
# ...                                                  ...  ...
# 55169  караоке 170623      звук кухня      персонал  ...  210
# 55170  друг клуб день рождение vipкомнату отлично кар...  342
# 55171  караоке клуб vip отлично музыка 2 час 2000 руб...  251
# 55173  пицца система лояльность раз цена обслуживание...  133
# 55174  пицца ребёнок интерьер интересный кактейли под...  149
#
#                                            split_reviews
# 0      в принципе, нормальный ресторанчик при отеле. ...
# 1      есть такой ресторан на юге москвы, по названию...
# 2      протяжении четырех часов!,с 1400 до 1800. цены...
# 3      вид из окна ночью на каширское шоссе и такое б...
# 4      брали салат из весеннего меню от шефповара рес...
# ...                                                  ...
# 55169  посещали данное караоке 17.06.23 , остались до...
# 55170  ходили с друзьями в клуб праздновать мое день ...
# 55171  хороший караоке клуб! бронировали vip. все отл...
# 55173  очень вкусная пицца. нравится их система лояль...
# 55174  пицца детям понравилась, интерьер очень интере...
#
# [43465 rows x 20 columns]

# %% [markdown]
# ## dff_7

# %%
dff_7 = dff_6.copy()
dff_7["split_reviews"] = dff_7["reviews"].apply(split_review)
dff_7
# Out:
#                place_id                                            reviews  \
# 0      4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1      4504127908348160  есть такой ресторан на юге москвы, по названию...
# 2      4504127908348342  прекрасные завтраки от 195 р. есть постные блю...
# 3      4504127908348384  крейзи! именно так можно сказать о данном заве...
# 4      4504127908348455  уютный семейный итальянский ресторан с плетено...
# ...                 ...                                                ...
# 9756  70000001091778278  заказала тортик, очень вкусный, свежий, заказы...
# 9757  70000001091778279  расположен на 4 этаже трц калейдоскоп, на фудк...
# 9758  70000001091778280  в целом вкусно, но раньше шаурмист прям большу...
# 9759  70000001091778281  бронировали vip комнату 4.02 на 6 человек и не...
# 9760  70000001091778283  очень вкусная пицца. нравится их система лояль...
#
#                                                features  \
# 0     бизнес-ланч, биточки, вкусная еда, гречотто, к...
# 1     бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# 2     завтраки, кофе с соевым молоком, милые надписи...
# 3     бесплатные концерты, веселая атмосфера, винило...
# 4     арматная, атмосфера, баклажаны, буррата, зелен...
# ...                                                 ...
# 9756  вкуснейший, вкусные десерты, вкусный, вкусняшк...
# 9757  ассортимент, известная специфика, сетевой рест...
# 9758     большая шаурма, вкусная шаурма, вкусно, лагман
# 9759  10% скидка, безупречное обслуживание, беспрово...
# 9760  атмосфера, вежливый персонал, вкусная еда, инт...
#
#                 name_primary         name_extension    city  \
# 0                        495  пивоваренный ресторан  Москва
# 1             Bora bora cafe               ресторан  Москва
# 2                     Coffee                кофейня  Москва
# 3             Bourbon street        пивной ресторан  Москва
# 4        Cantinetta Antinori               ресторан  Москва
# ...                      ...                    ...     ...
# 9756      особенный наполеон               ресторан  Москва
# 9757        вкусно — и точка    грузинский ресторан  Москва
# 9758             душа лаваша               ресторан  Москва
# 9759      караоке-клуб маска               ресторан  Москва
# 9760  petruccio. pizza&pasta               ресторан  Москва
#
#                                    address        lat        lon  \
# 0               Олимпийский проспект, 18/1  55.785009  37.624123
# 1                   Ореховый бульвар, 14к3  55.609493  37.719954
# 2                     Душинская улица, 7с1  55.745250  37.706002
# 3     Большой Златоустинский переулок, 7с1  55.758709  37.632634
# 4                    Денежный переулок, 20  55.745428  37.586787
# ...                                    ...        ...        ...
# 9756              Мосфильмовская улица, 53  55.704864  37.497450
# 9757                 Сходненская улица, 56  55.850499  37.444422
# 9758        Краснопролетарская улица, 16с1  55.777089  37.607197
# 9759                  улица Маросейка, 7/8  55.757592  37.632880
# 9760               улица Юных Ленинцев, 52  55.699796  37.765354
#
#       rating_decimal  ...                                      reviews_clean  \
# 0                5.0  ...  принцип нормальный ресторанчик отель выезд ход...
# 1                4.0  ...  ресторан юг москва название    окунуться франц...
# 2                5.0  ...  прекрасный завтрак 195 постный блюдо кофе соев...
# 3                4.9  ...  крейзи сказать заведение весело сделать дух ан...
# 4                5.0  ...  уютный семейный итальянский ресторан плетёный ...
# ...              ...  ...                                                ...
# 9756             2.0  ...  заказать тортик вкусный свежий заказывать день...
# 9757             4.0  ...  расположен 4 этаж трц калейдоскоп фудкорте сет...
# 9758             4.0  ...  целое вкусно ранний шаурмист больший шаурму де...
# 9759             5.0  ...  бронировать vip комната 402 6 человек пожалеть...
# 9760             5.0  ...  вкусный пицца нравиться система лояльность раз...
#
#                                          features_clean  \
# 0     бизнесланч биточки вкусный еда гречотто кофе л...
# 1     бизнесланчи вкусный еда вкусный стейк деловой ...
# 2     завтрак кофе соевый молоко милый надпись постн...
# 3     бесплатный концерт весёлый атмосфера виниловый...
# 4     арматная атмосфера баклажаны буррата зелень ин...
# ...                                                 ...
# 9756  вкуснейший вкусный десерт вкусный вкусняшки пр...
# 9757  ассортимент известный специфика сетевой рестор...
# 9758        больший шаурма вкусный шаурма вкусно лагман
# 9759  10 скидка безупречный обслуживание беспроводны...
# 9760  атмосфера вежливый персонал вкусный еда интере...
#
#                                  reviews_clean_no_verbs  \
# 0     принцип нормальный ресторанчик отель выезд сюд...
# 1     ресторан юг москва название     французский по...
# 2     прекрасный завтрак 195 постный блюдо кофе соев...
# 3     заведение весело дух английский паб частенько ...
# 4     уютный семейный итальянский ресторан плетёный ...
# ...                                                 ...
# 9756  тортик вкусный свежий день рождение спасибо бо...
# 9757  расположен 4 этаж трц калейдоскоп фудкорте сет...
# 9758  целое вкусно ранний шаурмист больший шаурму вк...
# 9759  vip комната 402 6 человек уютный комната беспр...
# 9760  вкусный пицца система лояльность раз приятно ц...
#
#                                 features_clean_no_verbs  \
# 0     бизнесланч биточки вкусный еда гречотто кофе л...
# 1     бизнесланчи вкусный еда вкусный стейк деловой ...
# 2     завтрак кофе соевый молоко милый надпись постн...
# 3     бесплатный концерт весёлый атмосфера виниловый...
# 4     арматная атмосфера баклажаны буррата зелень ин...
# ...                                                 ...
# 9756  вкусный десерт вкусный вкусняшки продукция неж...
# 9757  ассортимент известный специфика сетевой рестор...
# 9758        больший шаурма вкусный шаурма вкусно лагман
# 9759  10 скидка безупречный обслуживание беспроводны...
# 9760  атмосфера вежливый персонал вкусный еда интере...
#
#                                    reviews_clean_no_adj  \
# 0     принцип ресторанчик отель выезд ходить сюда би...
# 1     ресторан юг москва название     окунуться поли...
# 2          завтрак 195 блюдо кофе молоко надпись стакан
# 3     крейзи сказать заведение сделать дух паб часте...
# 4     ресторан мебель интерьер стиль дом     иметься...
# ...                                                 ...
# 9756  заказать тортик заказывать день рождение понра...
# 9757  4 этаж трц калейдоскоп фудкорте ресторан многи...
# 9758  вкусно шаурмист шаурму делать уменьшиться плюс...
# 9759  бронировать vip комната 402 6 человек пожалеть...
# 9760  пицца нравиться система лояльность раз сбивать...
#
#                                   features_clean_no_adj  \
# 0     бизнесланч биточки еда гречотто кофе латте цен...
# 1     еда стейк обед стиль мастерклассы доверие кухн...
# 2                     завтрак кофе молоко надпись блюдо
# 3     концерт атмосфера пластинка коктейль диваны му...
# 4     атмосфера баклажаны буррата зелень интерьер за...
# ...                                                 ...
# 9756  вкуснейший десерт вкусняшки продукция персонал...
# 9757             ассортимент специфика ресторан фудкорт
# 9758                               шаурма шаурма вкусно
# 9759  10 скидка обслуживание микрофон хостес еда кух...
# 9760  атмосфера персонал еда интерьер коктейли подач...
#
#                           reviews_clean_no_verbs_no_adj  \
# 0     принцип ресторанчик отель выезд сюда бизнеслан...
# 1     ресторан юг москва название      полинезия бер...
# 2          завтрак 195 блюдо кофе молоко надпись стакан
# 3     заведение дух паб частенько стойка гарна дивчи...
# 4     ресторан мебель интерьер стиль дом      веранд...
# ...                                                 ...
# 9756  тортик день рождение спасибо тортмагазин район...
# 9757  4 этаж трц калейдоскоп фудкорте ресторан многи...
# 9758  вкусно шаурмист шаурму плюс лагман волос время...
# 9759  vip комната 402 6 человек комната микрофон кач...
# 9760  пицца система лояльность раз цена обслуживание...
#
#                          features_clean_no_verbs_no_adj  len  \
# 0     бизнесланч биточки еда гречотто кофе латте цен...   80
# 1     еда стейк обед стиль мастерклассы доверие кухн...  199
# 2                     завтрак кофе молоко надпись блюдо   33
# 3     концерт атмосфера пластинка коктейль диваны му...  141
# 4     атмосфера баклажаны буррата зелень интерьер за...  128
# ...                                                 ...  ...
# 9756  десерт вкусняшки продукция персонал фрукт фрук...   77
# 9757             ассортимент специфика ресторан фудкорт   38
# 9758                               шаурма шаурма вкусно   20
# 9759  10 скидка обслуживание микрофон хостес еда кух...  148
# 9760  атмосфера персонал еда интерьер коктейли подач...   85
#
#                                           split_reviews
# 0     [в принципе, нормальный ресторанчик при отеле....
# 1     [есть такой ресторан на юге москвы, по названи...
# 2     [прекрасные завтраки от 195 р. есть постные бл...
# 3     [крейзи! именно так можно сказать о данном зав...
# 4     [уютный семейный итальянский ресторан с плетен...
# ...                                                 ...
# 9756  [заказала тортик, очень вкусный, свежий, заказ...
# 9757  [расположен на 4 этаже трц калейдоскоп, на фуд...
# 9758  [в целом вкусно, но раньше шаурмист прям больш...
# 9759  [бронировали vip комнату 4.02 на 6 человек и н...
# 9760  [очень вкусная пицца. нравится их система лоял...
#
# [9645 rows x 25 columns]

# %%
dff_7 = dff_7[dff_7["split_reviews"].apply(lambda x: len(x) > 0)]
dff_7 = dff_7.explode("split_reviews").reset_index(drop=True)
dff_7
# Out:
#                 place_id                                            reviews  \
# 0       4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1       4504127908348160  есть такой ресторан на юге москвы, по названию...
# 2       4504127908348160  есть такой ресторан на юге москвы, по названию...
# 3       4504127908348160  есть такой ресторан на юге москвы, по названию...
# 4       4504127908348160  есть такой ресторан на юге москвы, по названию...
# ...                  ...                                                ...
# 27564  70000001091778280  в целом вкусно, но раньше шаурмист прям большу...
# 27565  70000001091778281  бронировали vip комнату 4.02 на 6 человек и не...
# 27566  70000001091778281  бронировали vip комнату 4.02 на 6 человек и не...
# 27567  70000001091778281  бронировали vip комнату 4.02 на 6 человек и не...
# 27568  70000001091778283  очень вкусная пицца. нравится их система лояль...
#
#                                                 features  \
# 0      бизнес-ланч, биточки, вкусная еда, гречотто, к...
# 1      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# 2      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# 3      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# 4      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# ...                                                  ...
# 27564     большая шаурма, вкусная шаурма, вкусно, лагман
# 27565  10% скидка, безупречное обслуживание, беспрово...
# 27566  10% скидка, безупречное обслуживание, беспрово...
# 27567  10% скидка, безупречное обслуживание, беспрово...
# 27568  атмосфера, вежливый персонал, вкусная еда, инт...
#
#                  name_primary         name_extension    city  \
# 0                         495  пивоваренный ресторан  Москва
# 1              Bora bora cafe               ресторан  Москва
# 2              Bora bora cafe               ресторан  Москва
# 3              Bora bora cafe               ресторан  Москва
# 4              Bora bora cafe               ресторан  Москва
# ...                       ...                    ...     ...
# 27564             душа лаваша               ресторан  Москва
# 27565      караоке-клуб маска               ресторан  Москва
# 27566      караоке-клуб маска               ресторан  Москва
# 27567      караоке-клуб маска               ресторан  Москва
# 27568  petruccio. pizza&pasta               ресторан  Москва
#
#                               address        lat        lon  rating_decimal  \
# 0          Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# 2              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# 3              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# 4              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# ...                               ...        ...        ...             ...
# 27564  Краснопролетарская улица, 16с1  55.777089  37.607197             4.0
# 27565            улица Маросейка, 7/8  55.757592  37.632880             5.0
# 27566            улица Маросейка, 7/8  55.757592  37.632880             5.0
# 27567            улица Маросейка, 7/8  55.757592  37.632880             5.0
# 27568         улица Юных Ленинцев, 52  55.699796  37.765354             5.0
#
#        ...                                      reviews_clean  \
# 0      ...  принцип нормальный ресторанчик отель выезд ход...
# 1      ...  ресторан юг москва название    окунуться франц...
# 2      ...  ресторан юг москва название    окунуться франц...
# 3      ...  ресторан юг москва название    окунуться франц...
# 4      ...  ресторан юг москва название    окунуться франц...
# ...    ...                                                ...
# 27564  ...  целое вкусно ранний шаурмист больший шаурму де...
# 27565  ...  бронировать vip комната 402 6 человек пожалеть...
# 27566  ...  бронировать vip комната 402 6 человек пожалеть...
# 27567  ...  бронировать vip комната 402 6 человек пожалеть...
# 27568  ...  вкусный пицца нравиться система лояльность раз...
#
#                                           features_clean  \
# 0      бизнесланч биточки вкусный еда гречотто кофе л...
# 1      бизнесланчи вкусный еда вкусный стейк деловой ...
# 2      бизнесланчи вкусный еда вкусный стейк деловой ...
# 3      бизнесланчи вкусный еда вкусный стейк деловой ...
# 4      бизнесланчи вкусный еда вкусный стейк деловой ...
# ...                                                  ...
# 27564        больший шаурма вкусный шаурма вкусно лагман
# 27565  10 скидка безупречный обслуживание беспроводны...
# 27566  10 скидка безупречный обслуживание беспроводны...
# 27567  10 скидка безупречный обслуживание беспроводны...
# 27568  атмосфера вежливый персонал вкусный еда интере...
#
#                                   reviews_clean_no_verbs  \
# 0      принцип нормальный ресторанчик отель выезд сюд...
# 1      ресторан юг москва название     французский по...
# 2      ресторан юг москва название     французский по...
# 3      ресторан юг москва название     французский по...
# 4      ресторан юг москва название     французский по...
# ...                                                  ...
# 27564  целое вкусно ранний шаурмист больший шаурму вк...
# 27565  vip комната 402 6 человек уютный комната беспр...
# 27566  vip комната 402 6 человек уютный комната беспр...
# 27567  vip комната 402 6 человек уютный комната беспр...
# 27568  вкусный пицца система лояльность раз приятно ц...
#
#                                  features_clean_no_verbs  \
# 0      бизнесланч биточки вкусный еда гречотто кофе л...
# 1      бизнесланчи вкусный еда вкусный стейк деловой ...
# 2      бизнесланчи вкусный еда вкусный стейк деловой ...
# 3      бизнесланчи вкусный еда вкусный стейк деловой ...
# 4      бизнесланчи вкусный еда вкусный стейк деловой ...
# ...                                                  ...
# 27564        больший шаурма вкусный шаурма вкусно лагман
# 27565  10 скидка безупречный обслуживание беспроводны...
# 27566  10 скидка безупречный обслуживание беспроводны...
# 27567  10 скидка безупречный обслуживание беспроводны...
# 27568  атмосфера вежливый персонал вкусный еда интере...
#
#                                     reviews_clean_no_adj  \
# 0      принцип ресторанчик отель выезд ходить сюда би...
# 1      ресторан юг москва название     окунуться поли...
# 2      ресторан юг москва название     окунуться поли...
# 3      ресторан юг москва название     окунуться поли...
# 4      ресторан юг москва название     окунуться поли...
# ...                                                  ...
# 27564  вкусно шаурмист шаурму делать уменьшиться плюс...
# 27565  бронировать vip комната 402 6 человек пожалеть...
# 27566  бронировать vip комната 402 6 человек пожалеть...
# 27567  бронировать vip комната 402 6 человек пожалеть...
# 27568  пицца нравиться система лояльность раз сбивать...
#
#                                    features_clean_no_adj  \
# 0      бизнесланч биточки еда гречотто кофе латте цен...
# 1      еда стейк обед стиль мастерклассы доверие кухн...
# 2      еда стейк обед стиль мастерклассы доверие кухн...
# 3      еда стейк обед стиль мастерклассы доверие кухн...
# 4      еда стейк обед стиль мастерклассы доверие кухн...
# ...                                                  ...
# 27564                               шаурма шаурма вкусно
# 27565  10 скидка обслуживание микрофон хостес еда кух...
# 27566  10 скидка обслуживание микрофон хостес еда кух...
# 27567  10 скидка обслуживание микрофон хостес еда кух...
# 27568  атмосфера персонал еда интерьер коктейли подач...
#
#                            reviews_clean_no_verbs_no_adj  \
# 0      принцип ресторанчик отель выезд сюда бизнеслан...
# 1      ресторан юг москва название      полинезия бер...
# 2      ресторан юг москва название      полинезия бер...
# 3      ресторан юг москва название      полинезия бер...
# 4      ресторан юг москва название      полинезия бер...
# ...                                                  ...
# 27564  вкусно шаурмист шаурму плюс лагман волос время...
# 27565  vip комната 402 6 человек комната микрофон кач...
# 27566  vip комната 402 6 человек комната микрофон кач...
# 27567  vip комната 402 6 человек комната микрофон кач...
# 27568  пицца система лояльность раз цена обслуживание...
#
#                           features_clean_no_verbs_no_adj  len  \
# 0      бизнесланч биточки еда гречотто кофе латте цен...   80
# 1      еда стейк обед стиль мастерклассы доверие кухн...  199
# 2      еда стейк обед стиль мастерклассы доверие кухн...  199
# 3      еда стейк обед стиль мастерклассы доверие кухн...  199
# 4      еда стейк обед стиль мастерклассы доверие кухн...  199
# ...                                                  ...  ...
# 27564                               шаурма шаурма вкусно   20
# 27565  10 скидка обслуживание микрофон хостес еда кух...  148
# 27566  10 скидка обслуживание микрофон хостес еда кух...  148
# 27567  10 скидка обслуживание микрофон хостес еда кух...  148
# 27568  атмосфера персонал еда интерьер коктейли подач...   85
#
#                                            split_reviews
# 0      в принципе, нормальный ресторанчик при отеле. ...
# 1      есть такой ресторан на юге москвы, по названию...
# 2      протяжении четырех часов!,с 1400 до 1800. цены...
# 3      вид из окна ночью на каширское шоссе и такое б...
# 4      брали салат из весеннего меню от шефповара рес...
# ...                                                  ...
# 27564  в целом вкусно, но раньше шаурмист прям большу...
# 27565  бронировали vip комнату 4.02 на 6 человек и не...
# 27566  ребята,отмечали день рождение,все понравилось,...
# 27567  незабываемый праздник. также не могу не вырази...
# 27568  очень вкусная пицца. нравится их система лояль...
#
# [27569 rows x 25 columns]

# %%
dff_7["len"] = dff_7["split_reviews"].apply(len)

grouped_stats = dff_7.groupby("source")["len"].describe()
display(grouped_stats)
# Out:
#           count        mean         std    min    25%    50%    75%    max
# source
# flamp   14041.0  462.063599   90.210840  100.0  491.0  495.0  497.0  500.0
# yandex  13528.0  393.838187  136.180861  100.0  272.0  491.0  496.0  500.0

# %%
dff_7 = dff_7[(dff_7["rating"] > 3) & (dff_7["rating_decimal"] > 3)]
dff_7
# Out:
#                 place_id                                            reviews  \
# 0       4504127908348140  в принципе, нормальный ресторанчик при отеле. ...
# 1       4504127908348160  есть такой ресторан на юге москвы, по названию...
# 2       4504127908348160  есть такой ресторан на юге москвы, по названию...
# 3       4504127908348160  есть такой ресторан на юге москвы, по названию...
# 4       4504127908348160  есть такой ресторан на юге москвы, по названию...
# ...                  ...                                                ...
# 27564  70000001091778280  в целом вкусно, но раньше шаурмист прям большу...
# 27565  70000001091778281  бронировали vip комнату 4.02 на 6 человек и не...
# 27566  70000001091778281  бронировали vip комнату 4.02 на 6 человек и не...
# 27567  70000001091778281  бронировали vip комнату 4.02 на 6 человек и не...
# 27568  70000001091778283  очень вкусная пицца. нравится их система лояль...
#
#                                                 features  \
# 0      бизнес-ланч, биточки, вкусная еда, гречотто, к...
# 1      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# 2      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# 3      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# 4      бизнес-ланчи, вкусная еда, вкусный стейк, дело...
# ...                                                  ...
# 27564     большая шаурма, вкусная шаурма, вкусно, лагман
# 27565  10% скидка, безупречное обслуживание, беспрово...
# 27566  10% скидка, безупречное обслуживание, беспрово...
# 27567  10% скидка, безупречное обслуживание, беспрово...
# 27568  атмосфера, вежливый персонал, вкусная еда, инт...
#
#                  name_primary         name_extension    city  \
# 0                         495  пивоваренный ресторан  Москва
# 1              Bora bora cafe               ресторан  Москва
# 2              Bora bora cafe               ресторан  Москва
# 3              Bora bora cafe               ресторан  Москва
# 4              Bora bora cafe               ресторан  Москва
# ...                       ...                    ...     ...
# 27564             душа лаваша               ресторан  Москва
# 27565      караоке-клуб маска               ресторан  Москва
# 27566      караоке-клуб маска               ресторан  Москва
# 27567      караоке-клуб маска               ресторан  Москва
# 27568  petruccio. pizza&pasta               ресторан  Москва
#
#                               address        lat        lon  rating_decimal  \
# 0          Олимпийский проспект, 18/1  55.785009  37.624123             5.0
# 1              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# 2              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# 3              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# 4              Ореховый бульвар, 14к3  55.609493  37.719954             4.0
# ...                               ...        ...        ...             ...
# 27564  Краснопролетарская улица, 16с1  55.777089  37.607197             4.0
# 27565            улица Маросейка, 7/8  55.757592  37.632880             5.0
# 27566            улица Маросейка, 7/8  55.757592  37.632880             5.0
# 27567            улица Маросейка, 7/8  55.757592  37.632880             5.0
# 27568         улица Юных Ленинцев, 52  55.699796  37.765354             5.0
#
#        ...                                      reviews_clean  \
# 0      ...  принцип нормальный ресторанчик отель выезд ход...
# 1      ...  ресторан юг москва название    окунуться франц...
# 2      ...  ресторан юг москва название    окунуться франц...
# 3      ...  ресторан юг москва название    окунуться франц...
# 4      ...  ресторан юг москва название    окунуться франц...
# ...    ...                                                ...
# 27564  ...  целое вкусно ранний шаурмист больший шаурму де...
# 27565  ...  бронировать vip комната 402 6 человек пожалеть...
# 27566  ...  бронировать vip комната 402 6 человек пожалеть...
# 27567  ...  бронировать vip комната 402 6 человек пожалеть...
# 27568  ...  вкусный пицца нравиться система лояльность раз...
#
#                                           features_clean  \
# 0      бизнесланч биточки вкусный еда гречотто кофе л...
# 1      бизнесланчи вкусный еда вкусный стейк деловой ...
# 2      бизнесланчи вкусный еда вкусный стейк деловой ...
# 3      бизнесланчи вкусный еда вкусный стейк деловой ...
# 4      бизнесланчи вкусный еда вкусный стейк деловой ...
# ...                                                  ...
# 27564        больший шаурма вкусный шаурма вкусно лагман
# 27565  10 скидка безупречный обслуживание беспроводны...
# 27566  10 скидка безупречный обслуживание беспроводны...
# 27567  10 скидка безупречный обслуживание беспроводны...
# 27568  атмосфера вежливый персонал вкусный еда интере...
#
#                                   reviews_clean_no_verbs  \
# 0      принцип нормальный ресторанчик отель выезд сюд...
# 1      ресторан юг москва название     французский по...
# 2      ресторан юг москва название     французский по...
# 3      ресторан юг москва название     французский по...
# 4      ресторан юг москва название     французский по...
# ...                                                  ...
# 27564  целое вкусно ранний шаурмист больший шаурму вк...
# 27565  vip комната 402 6 человек уютный комната беспр...
# 27566  vip комната 402 6 человек уютный комната беспр...
# 27567  vip комната 402 6 человек уютный комната беспр...
# 27568  вкусный пицца система лояльность раз приятно ц...
#
#                                  features_clean_no_verbs  \
# 0      бизнесланч биточки вкусный еда гречотто кофе л...
# 1      бизнесланчи вкусный еда вкусный стейк деловой ...
# 2      бизнесланчи вкусный еда вкусный стейк деловой ...
# 3      бизнесланчи вкусный еда вкусный стейк деловой ...
# 4      бизнесланчи вкусный еда вкусный стейк деловой ...
# ...                                                  ...
# 27564        больший шаурма вкусный шаурма вкусно лагман
# 27565  10 скидка безупречный обслуживание беспроводны...
# 27566  10 скидка безупречный обслуживание беспроводны...
# 27567  10 скидка безупречный обслуживание беспроводны...
# 27568  атмосфера вежливый персонал вкусный еда интере...
#
#                                     reviews_clean_no_adj  \
# 0      принцип ресторанчик отель выезд ходить сюда би...
# 1      ресторан юг москва название     окунуться поли...
# 2      ресторан юг москва название     окунуться поли...
# 3      ресторан юг москва название     окунуться поли...
# 4      ресторан юг москва название     окунуться поли...
# ...                                                  ...
# 27564  вкусно шаурмист шаурму делать уменьшиться плюс...
# 27565  бронировать vip комната 402 6 человек пожалеть...
# 27566  бронировать vip комната 402 6 человек пожалеть...
# 27567  бронировать vip комната 402 6 человек пожалеть...
# 27568  пицца нравиться система лояльность раз сбивать...
#
#                                    features_clean_no_adj  \
# 0      бизнесланч биточки еда гречотто кофе латте цен...
# 1      еда стейк обед стиль мастерклассы доверие кухн...
# 2      еда стейк обед стиль мастерклассы доверие кухн...
# 3      еда стейк обед стиль мастерклассы доверие кухн...
# 4      еда стейк обед стиль мастерклассы доверие кухн...
# ...                                                  ...
# 27564                               шаурма шаурма вкусно
# 27565  10 скидка обслуживание микрофон хостес еда кух...
# 27566  10 скидка обслуживание микрофон хостес еда кух...
# 27567  10 скидка обслуживание микрофон хостес еда кух...
# 27568  атмосфера персонал еда интерьер коктейли подач...
#
#                            reviews_clean_no_verbs_no_adj  \
# 0      принцип ресторанчик отель выезд сюда бизнеслан...
# 1      ресторан юг москва название      полинезия бер...
# 2      ресторан юг москва название      полинезия бер...
# 3      ресторан юг москва название      полинезия бер...
# 4      ресторан юг москва название      полинезия бер...
# ...                                                  ...
# 27564  вкусно шаурмист шаурму плюс лагман волос время...
# 27565  vip комната 402 6 человек комната микрофон кач...
# 27566  vip комната 402 6 человек комната микрофон кач...
# 27567  vip комната 402 6 человек комната микрофон кач...
# 27568  пицца система лояльность раз цена обслуживание...
#
#                           features_clean_no_verbs_no_adj  len  \
# 0      бизнесланч биточки еда гречотто кофе латте цен...  492
# 1      еда стейк обед стиль мастерклассы доверие кухн...  493
# 2      еда стейк обед стиль мастерклассы доверие кухн...  499
# 3      еда стейк обед стиль мастерклассы доверие кухн...  495
# 4      еда стейк обед стиль мастерклассы доверие кухн...  492
# ...                                                  ...  ...
# 27564                               шаурма шаурма вкусно  499
# 27565  10 скидка обслуживание микрофон хостес еда кух...  495
# 27566  10 скидка обслуживание микрофон хостес еда кух...  494
# 27567  10 скидка обслуживание микрофон хостес еда кух...  444
# 27568  атмосфера персонал еда интерьер коктейли подач...  283
#
#                                            split_reviews
# 0      в принципе, нормальный ресторанчик при отеле. ...
# 1      есть такой ресторан на юге москвы, по названию...
# 2      протяжении четырех часов!,с 1400 до 1800. цены...
# 3      вид из окна ночью на каширское шоссе и такое б...
# 4      брали салат из весеннего меню от шефповара рес...
# ...                                                  ...
# 27564  в целом вкусно, но раньше шаурмист прям большу...
# 27565  бронировали vip комнату 4.02 на 6 человек и не...
# 27566  ребята,отмечали день рождение,все понравилось,...
# 27567  незабываемый праздник. также не могу не вырази...
# 27568  очень вкусная пицца. нравится их система лояль...
#
# [24303 rows x 25 columns]

# %%
dff_7.dropna(
    subset=["split_reviews"],
    inplace=True,
)
# Out:
# C:\Users\zPad\AppData\Local\Temp\ipykernel_21180\3843643356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_7.dropna(

# %%
dff_7.drop_duplicates(
    subset=[
        "split_reviews",
    ],
    inplace=True,
)
# Out:
# C:\Users\zPad\AppData\Local\Temp\ipykernel_21180\213711714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_7.drop_duplicates(

# %%
dff_7.drop(
    columns=[
        "reviews",
        "features",
        "reviews_clean",
        "features_clean",
        "reviews_clean_no_verbs",
        "features_clean_no_verbs",
        "reviews_clean_no_adj",
        "features_clean_no_adj",
        "reviews_clean_no_verbs_no_adj",
    ],
    inplace=True,
)
# Out:
# C:\Users\zPad\AppData\Local\Temp\ipykernel_21180\2970901392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_7.drop(

# %%
dff_7
# Out:
#                 place_id            name_primary         name_extension  \
# 0       4504127908348140                     495  пивоваренный ресторан
# 1       4504127908348160          Bora bora cafe               ресторан
# 2       4504127908348160          Bora bora cafe               ресторан
# 3       4504127908348160          Bora bora cafe               ресторан
# 4       4504127908348160          Bora bora cafe               ресторан
# ...                  ...                     ...                    ...
# 27564  70000001091778280             душа лаваша               ресторан
# 27565  70000001091778281      караоке-клуб маска               ресторан
# 27566  70000001091778281      караоке-клуб маска               ресторан
# 27567  70000001091778281      караоке-клуб маска               ресторан
# 27568  70000001091778283  petruccio. pizza&pasta               ресторан
#
#          city                         address        lat        lon  \
# 0      Москва      Олимпийский проспект, 18/1  55.785009  37.624123
# 1      Москва          Ореховый бульвар, 14к3  55.609493  37.719954
# 2      Москва          Ореховый бульвар, 14к3  55.609493  37.719954
# 3      Москва          Ореховый бульвар, 14к3  55.609493  37.719954
# 4      Москва          Ореховый бульвар, 14к3  55.609493  37.719954
# ...       ...                             ...        ...        ...
# 27564  Москва  Краснопролетарская улица, 16с1  55.777089  37.607197
# 27565  Москва            улица Маросейка, 7/8  55.757592  37.632880
# 27566  Москва            улица Маросейка, 7/8  55.757592  37.632880
# 27567  Москва            улица Маросейка, 7/8  55.757592  37.632880
# 27568  Москва         улица Юных Ленинцев, 52  55.699796  37.765354
#
#        rating_decimal  reviews_count  business_lunch  avg_price  rating  \
# 0                 5.0              1             0.0     1500.0     5.0
# 1                 4.0              3             1.0     1500.0     5.0
# 2                 4.0              3             1.0     1500.0     5.0
# 3                 4.0              3             1.0     1500.0     5.0
# 4                 4.0              3             1.0     1500.0     5.0
# ...               ...            ...             ...        ...     ...
# 27564             4.0              1             0.0        NaN     4.0
# 27565             5.0              5             0.0        NaN     5.0
# 27566             5.0              5             0.0        NaN     5.0
# 27567             5.0              5             0.0        NaN     5.0
# 27568             5.0              3             0.0        NaN     5.0
#
#        source                     features_clean_no_verbs_no_adj  len  \
# 0       flamp  бизнесланч биточки еда гречотто кофе латте цен...  492
# 1       flamp  еда стейк обед стиль мастерклассы доверие кухн...  493
# 2       flamp  еда стейк обед стиль мастерклассы доверие кухн...  499
# 3       flamp  еда стейк обед стиль мастерклассы доверие кухн...  495
# 4       flamp  еда стейк обед стиль мастерклассы доверие кухн...  492
# ...       ...                                                ...  ...
# 27564  yandex                               шаурма шаурма вкусно  499
# 27565  yandex  10 скидка обслуживание микрофон хостес еда кух...  495
# 27566  yandex  10 скидка обслуживание микрофон хостес еда кух...  494
# 27567  yandex  10 скидка обслуживание микрофон хостес еда кух...  444
# 27568  yandex  атмосфера персонал еда интерьер коктейли подач...  283
#
#                                            split_reviews
# 0      в принципе, нормальный ресторанчик при отеле. ...
# 1      есть такой ресторан на юге москвы, по названию...
# 2      протяжении четырех часов!,с 1400 до 1800. цены...
# 3      вид из окна ночью на каширское шоссе и такое б...
# 4      брали салат из весеннего меню от шефповара рес...
# ...                                                  ...
# 27564  в целом вкусно, но раньше шаурмист прям большу...
# 27565  бронировали vip комнату 4.02 на 6 человек и не...
# 27566  ребята,отмечали день рождение,все понравилось,...
# 27567  незабываемый праздник. также не могу не вырази...
# 27568  очень вкусная пицца. нравится их система лояль...
#
# [24303 rows x 16 columns]

# %%
dff_7.to_csv("review_flamp_yandex_v7_keys_exploaded.csv", index=False)
